# %% [markdown]
# ### Import Dependencies

# %%
import os
import pathlib
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import datasets, transforms
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ### Import Datasets and Get Classes

# %%
for dirpath, dirnames, filenames in os.walk("Dataset"):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in {dirpath}")

bean_class = len(os.listdir("Dataset/train"))

dataset_dir = pathlib.Path("Dataset/train")
class_names = np.array(sorted([item.name for item in dataset_dir.glob("*")]))
print(class_names)
# Out:
# There are 3 directories and 0 images in Dataset
# There are 2 directories and 0 images in Dataset\test
# There are 0 directories and 500 images in Dataset\test\Defected
# There are 0 directories and 500 images in Dataset\test\Undefected
# There are 2 directories and 0 images in Dataset\train
# There are 0 directories and 1500 images in Dataset\train\Defected
# There are 0 directories and 1500 images in Dataset\train\Undefected
# There are 2 directories and 0 images in Dataset\val
# There are 0 directories and 500 images in Dataset\val\Defected
# There are 0 directories and 500 images in Dataset\val\Undefected
# ['Defected' 'Undefected']

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# ##### Call the dataset

# %%
resize_transform = transforms.Compose([
    transforms.Resize((256, 256)),
])

image_dataset = datasets.ImageFolder(root='Dataset/train/',transform=resize_transform)

# %% [markdown]
# ##### Show image example in each class

# %%
# Define the classes of your dataset
classes = image_dataset.classes

# Create a figure with subplots for each class
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Loop through each class and plot the first image
for i, cls in enumerate(classes):
    # Get the indices of the images for this class
    indices = [j for j, (x, y) in enumerate(image_dataset) if y == i]
    # Get the first image for this class
    img = image_dataset[indices[0]][0]
    img = img.resize((256,256))
    # Plot the image on the corresponding subplot
    axes[i].imshow(img)
    axes[i].set_title(cls)

plt.show()

# %% [markdown]
# ##### Create image preprocessing

# %%
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize( [0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])

# %% [markdown]
# ##### Show image transformation

# %%
image_dataset = datasets.ImageFolder(root='Dataset/train/')

example_image, _ = image_dataset[0]
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(example_image)
ax[0].set_title('Before transform')
transformed_image = transform(example_image)
ax[1].imshow(transformed_image.permute(1, 2, 0))
ax[1].set_title('After transform')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### ResNet50 Model Building

# %% [markdown]
# ##### Hyperparameter Setup

# %%
num_classes = 2
batch_size = 64
num_epochs = 64
learning_rate = 0.0001

# %% [markdown]
# ##### Apply preprocessing to transform the dataset

# %%
train_set = datasets.ImageFolder(root='Dataset/train/', transform=transform)
train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True)

val_set = datasets.ImageFolder(root='Dataset/val/', transform=transform)
val_loader = torch.utils.data.DataLoader(val_set, batch_size=batch_size, shuffle=False)

test_set = datasets.ImageFolder(root='Dataset/test/', transform=transform)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ##### Load pre-trained ResNet50 model

# %%
resnet50 = models.resnet50(pretrained=True)

# %%
# Freeze all layers in the pre-trained model
for param in resnet50.parameters():
    param.requires_grad = False

# %%
# Replace the last fully connected layer with a new one
num_ftrs = resnet50.fc.in_features
resnet50.fc = nn.Linear(num_ftrs, num_classes)

# %% [markdown]
# ##### Define loss function and optimizer

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(resnet50.fc.parameters(), lr=learning_rate)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
resnet50.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=2, bias=True)
# )

# %% [markdown]
# ### Train and Validate Model

# %% [markdown]
# ##### Train the model

# %%
# Train the model
train_losses = []
train_accs = []
val_losses = []
val_accs = []

# Iterate over the validation dataset in batches
train_predictions = np.array([])
train_ground_truths = np.array([])

for epoch in range(num_epochs):
    # Training
    resnet50.train()
    train_loss = 0.0
    train_total = 0
    train_correct = 0
    
    for i, (images, labels) in enumerate(train_loader):
        images = images.cuda()
        labels = labels.cuda()
        
        optimizer.zero_grad()
        
        outputs = resnet50(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item() * labels.size(0)
        _, predicted = torch.max(outputs.data, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()
        
    train_losses.append(train_loss/train_total)
    train_accs.append(train_correct/train_total)
    
    # Validation
    resnet50.eval()
    val_loss = 0.0
    val_total = 0
    val_correct = 0
    
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.cuda()
            labels = labels.cuda()
            
            outputs = resnet50(images)
            loss = criterion(outputs, labels)

            train_predictions = np.concatenate((train_predictions, predicted.cpu().numpy()))
            train_ground_truths = np.concatenate((train_ground_truths, labels.cpu().numpy()))

            val_loss += loss.item() * labels.size(0)
            _, predicted = torch.max(outputs.data, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()
        
        # remove the extra predictions
        if len(train_predictions) > len(train_ground_truths):
            train_predictions = train_predictions[:len(train_ground_truths)]

    # Convert predictions and true labels to numpy arrays
    train_predictions = np.array(train_predictions)
    train_ground_truths = np.array(train_ground_truths)
    
    val_losses.append(val_loss/val_total)
    val_accs.append(val_correct/val_total)
    
    # Print epoch statistics
    print('Epoch [{}/{}], Train Loss: {:.4f}, Train Acc: {:.4f}, Val Loss: {:.4f}, Val Acc: {:.4f}'
          .format(epoch+1, num_epochs, train_losses[-1], train_accs[-1], val_losses[-1], val_accs[-1]))
# Out:
# Epoch [1/64], Train Loss: 0.6449, Train Acc: 0.6533, Val Loss: 0.5932, Val Acc: 0.7730
# Epoch [2/64], Train Loss: 0.5541, Train Acc: 0.8107, Val Loss: 0.5117, Val Acc: 0.8440
# Epoch [3/64], Train Loss: 0.4934, Train Acc: 0.8453, Val Loss: 0.4617, Val Acc: 0.8590
# Epoch [4/64], Train Loss: 0.4476, Train Acc: 0.8627, Val Loss: 0.4253, Val Acc: 0.8680
# Epoch [5/64], Train Loss: 0.4164, Train Acc: 0.8780, Val Loss: 0.3984, Val Acc: 0.8830
# Epoch [6/64], Train Loss: 0.3890, Train Acc: 0.8833, Val Loss: 0.3710, Val Acc: 0.8930
# Epoch [7/64], Train Loss: 0.3656, Train Acc: 0.8920, Val Loss: 0.3527, Val Acc: 0.8920
# Epoch [8/64], Train Loss: 0.3505, Train Acc: 0.8917, Val Loss: 0.3330, Val Acc: 0.8950
# Epoch [9/64], Train Loss: 0.3376, Train Acc: 0.8967, Val Loss: 0.3256, Val Acc: 0.9000
# Epoch [10/64], Train Loss: 0.3179, Train Acc: 0.9047, Val Loss: 0.3023, Val Acc: 0.9200
# Epoch [11/64], Train Loss: 0.3090, Train Acc: 0.9140, Val Loss: 0.2936, Val Acc: 0.9130
# Epoch [12/64], Train Loss: 0.2966, Train Acc: 0.9163, Val Loss: 0.2850, Val Acc: 0.9170
# Epoch [13/64], Train Loss: 0.2905, Train Acc: 0.9140, Val Loss: 0.2762, Val Acc: 0.9180
# Epoch [14/64], Train Loss: 0.2835, Train Acc: 0.9160, Val Loss: 0.2666, Val Acc: 0.9190
# Epoch [15/64], Train Loss: 0.2766, Train Acc: 0.9197, Val Loss: 0.2604, Val Acc: 0.9250
# Epoch [16/64], Train Loss: 0.2689, Train Acc: 0.9210, Val Loss: 0.2563, Val Acc: 0.9250
# Epoch [17/64], Train Loss: 0.2659, Train Acc: 0.9217, Val Loss: 0.2475, Val Acc: 0.9360
# Epoch [18/64], Train Loss: 0.2517, Train Acc: 0.9267, Val Loss: 0.2453, Val Acc: 0.9330
# Epoch [19/64], Train Loss: 0.2519, Train Acc: 0.9197, Val Loss: 0.2348, Val Acc: 0.9270
# Epoch [20/64], Train Loss: 0.2490, Train Acc: 0.9297, Val Loss: 0.2339, Val Acc: 0.9290
# Epoch [21/64], Train Loss: 0.2404, Train Acc: 0.9283, Val Loss: 0.2306, Val Acc: 0.9270
# Epoch [22/64], Train Loss: 0.2348, Train Acc: 0.9283, Val Loss: 0.2274, Val Acc: 0.9290
# Epoch [23/64], Train Loss: 0.2318, Train Acc: 0.9307, Val Loss: 0.2205, Val Acc: 0.9280
# Epoch [24/64], Train Loss: 0.2285, Train Acc: 0.9367, Val Loss: 0.2152, Val Acc: 0.9360
# Epoch [25/64], Train Loss: 0.2252, Train Acc: 0.9323, Val Loss: 0.2112, Val Acc: 0.9370
# Epoch [26/64], Train Loss: 0.2249, Train Acc: 0.9350, Val Loss: 0.2045, Val Acc: 0.9450
# Epoch [27/64], Train Loss: 0.2172, Train Acc: 0.9417, Val Loss: 0.2036, Val Acc: 0.9430
# Epoch [28/64], Train Loss: 0.2149, Train Acc: 0.9353, Val Loss: 0.2037, Val Acc: 0.9370
# Epoch [29/64], Train Loss: 0.2089, Train Acc: 0.9390, Val Loss: 0.1991, Val Acc: 0.9400
# Epoch [30/64], Train Loss: 0.2053, Train Acc: 0.9430, Val Loss: 0.1915, Val Acc: 0.9560
# Epoch [31/64], Train Loss: 0.2070, Train Acc: 0.9437, Val Loss: 0.1914, Val Acc: 0.9460
# Epoch [32/64], Train Loss: 0.2082, Train Acc: 0.9320, Val Loss: 0.1926, Val Acc: 0.9370
# Epoch [33/64], Train Loss: 0.2014, Train Acc: 0.9383, Val Loss: 0.1897, Val Acc: 0.9410
# Epoch [34/64], Train Loss: 0.1963, Train Acc: 0.9440, Val Loss: 0.1896, Val Acc: 0.9450
# Epoch [35/64], Train Loss: 0.1956, Train Acc: 0.9423, Val Loss: 0.1866, Val Acc: 0.9440
# Epoch [36/64], Train Loss: 0.1992, Train Acc: 0.9403, Val Loss: 0.1783, Val Acc: 0.9510
# Epoch [37/64], Train Loss: 0.1953, Train Acc: 0.9390, Val Loss: 0.1779, Val Acc: 0.9490
# Epoch [38/64], Train Loss: 0.1841, Train Acc: 0.9510, Val Loss: 0.1740, Val Acc: 0.9480
# Epoch [39/64], Train Loss: 0.1946, Train Acc: 0.9400, Val Loss: 0.1767, Val Acc: 0.9430
# Epoch [40/64], Train Loss: 0.1896, Train Acc: 0.9443, Val Loss: 0.1764, Val Acc: 0.9450
# Epoch [41/64], Train Loss: 0.1852, Train Acc: 0.9433, Val Loss: 0.1713, Val Acc: 0.9560
# Epoch [42/64], Train Loss: 0.1792, Train Acc: 0.9483, Val Loss: 0.1703, Val Acc: 0.9470
# Epoch [43/64], Train Loss: 0.1877, Train Acc: 0.9400, Val Loss: 0.1711, Val Acc: 0.9510
# Epoch [44/64], Train Loss: 0.1894, Train Acc: 0.9403, Val Loss: 0.1646, Val Acc: 0.9540
# Epoch [45/64], Train Loss: 0.1771, Train Acc: 0.9440, Val Loss: 0.1705, Val Acc: 0.9490
# Epoch [46/64], Train Loss: 0.1725, Train Acc: 0.9510, Val Loss: 0.1641, Val Acc: 0.9560
# Epoch [47/64], Train Loss: 0.1743, Train Acc: 0.9463, Val Loss: 0.1634, Val Acc: 0.9490
# Epoch [48/64], Train Loss: 0.1748, Train Acc: 0.9500, Val Loss: 0.1702, Val Acc: 0.9420
# Epoch [49/64], Train Loss: 0.1728, Train Acc: 0.9487, Val Loss: 0.1614, Val Acc: 0.9460
# Epoch [50/64], Train Loss: 0.1694, Train Acc: 0.9443, Val Loss: 0.1717, Val Acc: 0.9430
# Epoch [51/64], Train Loss: 0.1642, Train Acc: 0.9497, Val Loss: 0.1652, Val Acc: 0.9460
# Epoch [52/64], Train Loss: 0.1647, Train Acc: 0.9530, Val Loss: 0.1602, Val Acc: 0.9510
# Epoch [53/64], Train Loss: 0.1710, Train Acc: 0.9490, Val Loss: 0.1577, Val Acc: 0.9490
# Epoch [54/64], Train Loss: 0.1673, Train Acc: 0.9497, Val Loss: 0.1647, Val Acc: 0.9450
# Epoch [55/64], Train Loss: 0.1683, Train Acc: 0.9440, Val Loss: 0.1557, Val Acc: 0.9500
# Epoch [56/64], Train Loss: 0.1666, Train Acc: 0.9477, Val Loss: 0.1454, Val Acc: 0.9570
# Epoch [57/64], Train Loss: 0.1643, Train Acc: 0.9487, Val Loss: 0.1570, Val Acc: 0.9520
# Epoch [58/64], Train Loss: 0.1604, Train Acc: 0.9517, Val Loss: 0.1555, Val Acc: 0.9510
# Epoch [59/64], Train Loss: 0.1561, Train Acc: 0.9523, Val Loss: 0.1533, Val Acc: 0.9490
# Epoch [60/64], Train Loss: 0.1582, Train Acc: 0.9557, Val Loss: 0.1490, Val Acc: 0.9560
# Epoch [61/64], Train Loss: 0.1556, Train Acc: 0.9533, Val Loss: 0.1470, Val Acc: 0.9540
# Epoch [62/64], Train Loss: 0.1530, Train Acc: 0.9540, Val Loss: 0.1466, Val Acc: 0.9550
# Epoch [63/64], Train Loss: 0.1578, Train Acc: 0.9510, Val Loss: 0.1488, Val Acc: 0.9570
# Epoch [64/64], Train Loss: 0.1609, Train Acc: 0.9493, Val Loss: 0.1462, Val Acc: 0.9590

# %% [markdown]
# ##### Plot losses and accuracy

# %%
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.legend()
plt.show()

plt.plot(train_accs, label='Train Acc')
plt.plot(val_accs, label='Val Acc')
plt.legend()
plt.show()

# %% [markdown]
# ##### Calculate the confusion matrix

# %%
cm = confusion_matrix(train_ground_truths, train_predictions)
labels_category = ['Defected', 'Undefected']
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels= labels_category, yticklabels=labels_category)
# Out:
# <Axes: >

# %% [markdown]
# ### Testing Model

# %% [markdown]
# ##### Set to evaluation mode

# %%
# Set the model to evaluation mode
resnet50.eval()

# Keep track of the validation loss and accuracy
test_loss = 0.0
test_correct = 0
test_total = 0

# %% [markdown]
# ##### Test the model

# %%
# Iterate over the validation dataset in batches
test_predictions = []
test_ground_truths = []

for images, labels in test_loader:
    images = images.cuda()
    labels = labels.cuda()
    # Forward pass
    outputs = resnet50(images)
    loss = criterion(outputs, labels)

    # Update the validation loss
    test_loss += loss.item() * labels.size(0)

    test_predictions.extend(predicted.cpu().numpy())
    test_ground_truths.extend(labels.cpu().numpy())

    # Update the testing accuracy
    _, predicted = torch.max(outputs.data, 1)
    test_total += labels.size(0)
    test_correct += (predicted == labels).sum().item()

# Compute the average testing loss and accuracy
test_loss /= len(test_set)
test_accuracy = 100 * test_correct / test_total

# Print the testing loss and accuracy
print(f'Testing loss: {test_loss:.4f}, accuracy: {test_accuracy:.2f}%')
# Out:
# Testing loss: 0.1552, accuracy: 94.70%

# %% [markdown]
# ##### Calculate the confusion matrix

# %%
# Calculate the confusion matrix
cm = confusion_matrix(test_ground_truths, test_predictions)
labels_category = ['Defected', 'Undefected']
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels= labels_category, yticklabels=labels_category)
# Out:
# <Axes: >

# %% [markdown]
# ##### Save the model

# %%
# Save the state_dict model to a file
torch.save(resnet50.state_dict(), 'resnet50-coffee-defect-state-dict.pth')

# Save the model to a file
torch.save(resnet50, 'resnet50-coffee-defect.pth')
