# %% [markdown]
# ### Import Dependencies

# %%
import os
import pathlib
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import datasets, transforms
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ### Import Datasets and Get Classes

# %%
for dirpath, dirnames, filenames in os.walk("Dataset"):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in {dirpath}")

bean_class = len(os.listdir("Dataset/train"))

dataset_dir = pathlib.Path("Dataset/train")
class_names = np.array(sorted([item.name for item in dataset_dir.glob("*")]))
print(class_names)
# Out:
# There are 3 directories and 0 images in Dataset
# There are 2 directories and 0 images in Dataset\test
# There are 0 directories and 500 images in Dataset\test\Defected
# There are 0 directories and 500 images in Dataset\test\Undefected
# There are 2 directories and 0 images in Dataset\train
# There are 0 directories and 1500 images in Dataset\train\Defected
# There are 0 directories and 1500 images in Dataset\train\Undefected
# There are 2 directories and 0 images in Dataset\val
# There are 0 directories and 500 images in Dataset\val\Defected
# There are 0 directories and 500 images in Dataset\val\Undefected
# ['Defected' 'Undefected']

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# ##### Call the dataset

# %%
resize_transform = transforms.Compose([
    transforms.Resize((256, 256)),
])

image_dataset = datasets.ImageFolder(root='Dataset/train/',transform=resize_transform)

# %% [markdown]
# ##### Show image example in each class

# %%
# Define the classes of your dataset
classes = image_dataset.classes

# Create a figure with subplots for each class
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Loop through each class and plot the first image
for i, cls in enumerate(classes):
    # Get the indices of the images for this class
    indices = [j for j, (x, y) in enumerate(image_dataset) if y == i]
    # Get the first image for this class
    img = image_dataset[indices[0]][0]
    img = img.resize((256,256))
    # Plot the image on the corresponding subplot
    axes[i].imshow(img)
    axes[i].set_title(cls)

plt.show()

# %% [markdown]
# ##### Create image preprocessing

# %%
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize( [0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])

# %% [markdown]
# ##### Show image transformation

# %%
image_dataset = datasets.ImageFolder(root='Dataset/train/')

example_image, _ = image_dataset[0]
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(example_image)
ax[0].set_title('Before transform')
transformed_image = transform(example_image)
ax[1].imshow(transformed_image.permute(1, 2, 0))
ax[1].set_title('After transform')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### ResNet50 Model Building

# %%
num_classes = 2
batch_size = 64
num_epochs = 64
learning_rate = 0.0001

# %% [markdown]
# ##### Apply preprocessing to transform the dataset

# %%
train_set = datasets.ImageFolder(root='Dataset/train/', transform=transform)
train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True)

val_set = datasets.ImageFolder(root='Dataset/val/', transform=transform)
val_loader = torch.utils.data.DataLoader(val_set, batch_size=batch_size, shuffle=False)

test_set = datasets.ImageFolder(root='Dataset/test/', transform=transform)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ##### Load pre-trained ResNet50 model

# %%
resnet50 = models.resnet50(pretrained=True)

# %%
# Freeze all layers in the pre-trained model
for param in resnet50.parameters():
    param.requires_grad = False

# %%
# Replace the last fully connected layer with a new one
num_ftrs = resnet50.fc.in_features
resnet50.fc = nn.Linear(num_ftrs, num_classes)

# %% [markdown]
# ##### Define loss function and optimizer

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(resnet50.fc.parameters(), lr=learning_rate)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
resnet50.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=2, bias=True)
# )

# %% [markdown]
# ### Train and Validate Model

# %% [markdown]
# ##### Train the model

# %%
# Train the model
train_losses = []
train_accs = []
val_losses = []
val_accs = []

# Iterate over the validation dataset in batches
train_predictions = np.array([])
train_ground_truths = np.array([])

for epoch in range(num_epochs):
    # Training
    resnet50.train()
    train_loss = 0.0
    train_total = 0
    train_correct = 0
    
    for i, (images, labels) in enumerate(train_loader):
        images = images.cuda()
        labels = labels.cuda()
        
        optimizer.zero_grad()
        
        outputs = resnet50(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item() * labels.size(0)
        _, predicted = torch.max(outputs.data, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()
        
    train_losses.append(train_loss/train_total)
    train_accs.append(train_correct/train_total)
    
    # Validation
    resnet50.eval()
    val_loss = 0.0
    val_total = 0
    val_correct = 0
    
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.cuda()
            labels = labels.cuda()
            
            outputs = resnet50(images)
            loss = criterion(outputs, labels)

            train_predictions = np.concatenate((train_predictions, predicted.cpu().numpy()))
            train_ground_truths = np.concatenate((train_ground_truths, labels.cpu().numpy()))

            val_loss += loss.item() * labels.size(0)
            _, predicted = torch.max(outputs.data, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()
        
        # remove the extra predictions
        if len(train_predictions) > len(train_ground_truths):
            train_predictions = train_predictions[:len(train_ground_truths)]

    # Convert predictions and true labels to numpy arrays
    train_predictions = np.array(train_predictions)
    train_ground_truths = np.array(train_ground_truths)
    
    val_losses.append(val_loss/val_total)
    val_accs.append(val_correct/val_total)
    
    # Print epoch statistics
    print('Epoch [{}/{}], Train Loss: {:.4f}, Train Acc: {:.4f}, Val Loss: {:.4f}, Val Acc: {:.4f}'
          .format(epoch+1, num_epochs, train_losses[-1], train_accs[-1], val_losses[-1], val_accs[-1]))
# Out:
# Epoch [1/64], Train Loss: 0.6543, Train Acc: 0.6420, Val Loss: 0.6224, Val Acc: 0.6480
# Epoch [2/64], Train Loss: 0.5778, Train Acc: 0.7880, Val Loss: 0.5519, Val Acc: 0.8030
# Epoch [3/64], Train Loss: 0.5171, Train Acc: 0.8447, Val Loss: 0.4931, Val Acc: 0.8550
# Epoch [4/64], Train Loss: 0.4726, Train Acc: 0.8690, Val Loss: 0.4527, Val Acc: 0.8660
# Epoch [5/64], Train Loss: 0.4343, Train Acc: 0.8907, Val Loss: 0.4195, Val Acc: 0.8890
# Epoch [6/64], Train Loss: 0.4044, Train Acc: 0.8880, Val Loss: 0.3875, Val Acc: 0.8920
# Epoch [7/64], Train Loss: 0.3826, Train Acc: 0.8983, Val Loss: 0.3649, Val Acc: 0.8980
# Epoch [8/64], Train Loss: 0.3616, Train Acc: 0.8970, Val Loss: 0.3494, Val Acc: 0.8920
# Epoch [9/64], Train Loss: 0.3481, Train Acc: 0.9010, Val Loss: 0.3304, Val Acc: 0.9180
# Epoch [10/64], Train Loss: 0.3308, Train Acc: 0.9030, Val Loss: 0.3212, Val Acc: 0.9090
# Epoch [11/64], Train Loss: 0.3164, Train Acc: 0.9153, Val Loss: 0.3020, Val Acc: 0.9230
# Epoch [12/64], Train Loss: 0.3038, Train Acc: 0.9210, Val Loss: 0.2947, Val Acc: 0.9230
# Epoch [13/64], Train Loss: 0.2977, Train Acc: 0.9150, Val Loss: 0.2827, Val Acc: 0.9230
# Epoch [14/64], Train Loss: 0.2864, Train Acc: 0.9140, Val Loss: 0.2793, Val Acc: 0.9210
# Epoch [15/64], Train Loss: 0.2845, Train Acc: 0.9163, Val Loss: 0.2780, Val Acc: 0.9190
# Epoch [16/64], Train Loss: 0.2709, Train Acc: 0.9250, Val Loss: 0.2529, Val Acc: 0.9400
# Epoch [17/64], Train Loss: 0.2697, Train Acc: 0.9210, Val Loss: 0.2487, Val Acc: 0.9340
# Epoch [18/64], Train Loss: 0.2564, Train Acc: 0.9273, Val Loss: 0.2532, Val Acc: 0.9340
# Epoch [19/64], Train Loss: 0.2507, Train Acc: 0.9320, Val Loss: 0.2414, Val Acc: 0.9290
# Epoch [20/64], Train Loss: 0.2482, Train Acc: 0.9327, Val Loss: 0.2391, Val Acc: 0.9350
# Epoch [21/64], Train Loss: 0.2367, Train Acc: 0.9380, Val Loss: 0.2356, Val Acc: 0.9360
# Epoch [22/64], Train Loss: 0.2369, Train Acc: 0.9307, Val Loss: 0.2342, Val Acc: 0.9270
# Epoch [23/64], Train Loss: 0.2321, Train Acc: 0.9347, Val Loss: 0.2249, Val Acc: 0.9330
# Epoch [24/64], Train Loss: 0.2277, Train Acc: 0.9370, Val Loss: 0.2260, Val Acc: 0.9350
# Epoch [25/64], Train Loss: 0.2254, Train Acc: 0.9370, Val Loss: 0.2122, Val Acc: 0.9480
# Epoch [26/64], Train Loss: 0.2339, Train Acc: 0.9290, Val Loss: 0.2105, Val Acc: 0.9400
# Epoch [27/64], Train Loss: 0.2170, Train Acc: 0.9377, Val Loss: 0.2094, Val Acc: 0.9350
# Epoch [28/64], Train Loss: 0.2243, Train Acc: 0.9320, Val Loss: 0.2089, Val Acc: 0.9360
# Epoch [29/64], Train Loss: 0.2103, Train Acc: 0.9413, Val Loss: 0.2064, Val Acc: 0.9370
# Epoch [30/64], Train Loss: 0.2141, Train Acc: 0.9330, Val Loss: 0.1949, Val Acc: 0.9440
# Epoch [31/64], Train Loss: 0.2089, Train Acc: 0.9390, Val Loss: 0.1949, Val Acc: 0.9420
# Epoch [32/64], Train Loss: 0.2105, Train Acc: 0.9360, Val Loss: 0.1961, Val Acc: 0.9390
# Epoch [33/64], Train Loss: 0.2009, Train Acc: 0.9480, Val Loss: 0.1923, Val Acc: 0.9450
# Epoch [34/64], Train Loss: 0.2034, Train Acc: 0.9400, Val Loss: 0.1832, Val Acc: 0.9490
# Epoch [35/64], Train Loss: 0.1962, Train Acc: 0.9380, Val Loss: 0.1856, Val Acc: 0.9490
# Epoch [36/64], Train Loss: 0.2018, Train Acc: 0.9403, Val Loss: 0.1821, Val Acc: 0.9500
# Epoch [37/64], Train Loss: 0.1915, Train Acc: 0.9420, Val Loss: 0.1840, Val Acc: 0.9490
# Epoch [38/64], Train Loss: 0.1902, Train Acc: 0.9450, Val Loss: 0.1882, Val Acc: 0.9380
# Epoch [39/64], Train Loss: 0.1862, Train Acc: 0.9457, Val Loss: 0.1805, Val Acc: 0.9500
# Epoch [40/64], Train Loss: 0.1845, Train Acc: 0.9460, Val Loss: 0.1776, Val Acc: 0.9460
# Epoch [41/64], Train Loss: 0.1871, Train Acc: 0.9420, Val Loss: 0.1772, Val Acc: 0.9510
# Epoch [42/64], Train Loss: 0.1831, Train Acc: 0.9467, Val Loss: 0.1737, Val Acc: 0.9500
# Epoch [43/64], Train Loss: 0.1829, Train Acc: 0.9433, Val Loss: 0.1716, Val Acc: 0.9450
# Epoch [44/64], Train Loss: 0.1853, Train Acc: 0.9413, Val Loss: 0.1690, Val Acc: 0.9510
# Epoch [45/64], Train Loss: 0.1912, Train Acc: 0.9407, Val Loss: 0.1648, Val Acc: 0.9570
# Epoch [46/64], Train Loss: 0.1807, Train Acc: 0.9440, Val Loss: 0.1704, Val Acc: 0.9490
# Epoch [47/64], Train Loss: 0.1817, Train Acc: 0.9370, Val Loss: 0.1754, Val Acc: 0.9390
# Epoch [48/64], Train Loss: 0.1784, Train Acc: 0.9443, Val Loss: 0.1721, Val Acc: 0.9420
# Epoch [49/64], Train Loss: 0.1722, Train Acc: 0.9453, Val Loss: 0.1600, Val Acc: 0.9530
# Epoch [50/64], Train Loss: 0.1780, Train Acc: 0.9460, Val Loss: 0.1694, Val Acc: 0.9460
# Epoch [51/64], Train Loss: 0.1724, Train Acc: 0.9437, Val Loss: 0.1646, Val Acc: 0.9530
# Epoch [52/64], Train Loss: 0.1672, Train Acc: 0.9503, Val Loss: 0.1533, Val Acc: 0.9540
# Epoch [53/64], Train Loss: 0.1702, Train Acc: 0.9470, Val Loss: 0.1624, Val Acc: 0.9540
# Epoch [54/64], Train Loss: 0.1657, Train Acc: 0.9507, Val Loss: 0.1552, Val Acc: 0.9530
# Epoch [55/64], Train Loss: 0.1650, Train Acc: 0.9520, Val Loss: 0.1562, Val Acc: 0.9500
# Epoch [56/64], Train Loss: 0.1706, Train Acc: 0.9467, Val Loss: 0.1598, Val Acc: 0.9440
# Epoch [57/64], Train Loss: 0.1709, Train Acc: 0.9473, Val Loss: 0.1600, Val Acc: 0.9500
# Epoch [58/64], Train Loss: 0.1728, Train Acc: 0.9433, Val Loss: 0.1609, Val Acc: 0.9410
# Epoch [59/64], Train Loss: 0.1680, Train Acc: 0.9453, Val Loss: 0.1477, Val Acc: 0.9610
# Epoch [60/64], Train Loss: 0.1661, Train Acc: 0.9480, Val Loss: 0.1469, Val Acc: 0.9570
# Epoch [61/64], Train Loss: 0.1605, Train Acc: 0.9527, Val Loss: 0.1578, Val Acc: 0.9460
# Epoch [62/64], Train Loss: 0.1646, Train Acc: 0.9517, Val Loss: 0.1536, Val Acc: 0.9550
# Epoch [63/64], Train Loss: 0.1585, Train Acc: 0.9523, Val Loss: 0.1504, Val Acc: 0.9520
# Epoch [64/64], Train Loss: 0.1575, Train Acc: 0.9497, Val Loss: 0.1498, Val Acc: 0.9520

# %% [markdown]
# ##### Plot losses and accuracy

# %%
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.legend()
plt.show()

plt.plot(train_accs, label='Train Acc')
plt.plot(val_accs, label='Val Acc')
plt.legend()
plt.show()

# %% [markdown]
# ##### Calculate the confusion matrix

# %%
cm = confusion_matrix(train_ground_truths, train_predictions)
labels_category = ['Defected', 'Undefected']
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels= labels_category, yticklabels=labels_category)
# Out:
# <Axes: >

# %% [markdown]
# ### Testing Model

# %% [markdown]
# ##### Set to evaluation mode

# %%
# Set the model to evaluation mode
resnet50.eval()

# Keep track of the validation loss and accuracy
test_loss = 0.0
test_correct = 0
test_total = 0

# %% [markdown]
# ##### Test the model

# %%
# Iterate over the validation dataset in batches
test_predictions = []
test_ground_truths = []

for images, labels in test_loader:
    images = images.cuda()
    labels = labels.cuda()
    # Forward pass
    outputs = resnet50(images)
    loss = criterion(outputs, labels)

    # Update the validation loss
    test_loss += loss.item() * labels.size(0)

    test_predictions.extend(predicted.cpu().numpy())
    test_ground_truths.extend(labels.cpu().numpy())

    # Update the testing accuracy
    _, predicted = torch.max(outputs.data, 1)
    test_total += labels.size(0)
    test_correct += (predicted == labels).sum().item()

# Compute the average testing loss and accuracy
test_loss /= len(test_set)
test_accuracy = 100 * test_correct / test_total

# Print the testing loss and accuracy
print(f'Testing loss: {test_loss:.4f}, accuracy: {test_accuracy:.2f}%')
# Out:
# Testing loss: 0.1573, accuracy: 94.60%

# %% [markdown]
# ##### Calculate the confusion matrix

# %%
# Calculate the confusion matrix
cm = confusion_matrix(test_ground_truths, test_predictions)
labels_category = ['Defected', 'Undefected']
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels= labels_category, yticklabels=labels_category)
# Out:
# <Axes: >
