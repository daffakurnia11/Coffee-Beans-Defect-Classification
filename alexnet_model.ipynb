# %% [markdown]
# ### Import Dependencies

# %%
import os
import pathlib
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import datasets, transforms
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ### Import Datasets and Get Classes

# %%
for dirpath, dirnames, filenames in os.walk("Dataset"):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in {dirpath}")

bean_class = len(os.listdir("Dataset/train"))

dataset_dir = pathlib.Path("Dataset/train")
class_names = np.array(sorted([item.name for item in dataset_dir.glob("*")]))
print(class_names)
# Out:
# There are 3 directories and 0 images in Dataset
# There are 2 directories and 0 images in Dataset\test
# There are 0 directories and 555 images in Dataset\test\Defected
# There are 0 directories and 555 images in Dataset\test\Undefected
# There are 2 directories and 0 images in Dataset\train
# There are 0 directories and 1555 images in Dataset\train\Defected
# There are 0 directories and 1555 images in Dataset\train\Undefected
# There are 2 directories and 0 images in Dataset\val
# There are 0 directories and 555 images in Dataset\val\Defected
# There are 0 directories and 555 images in Dataset\val\Undefected
# ['Defected' 'Undefected']

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# ##### Call the dataset

# %%
resize_transform = transforms.Compose([
    transforms.Resize((256, 256)),
])

image_dataset = datasets.ImageFolder(root='Dataset/train/',transform=resize_transform)

# %% [markdown]
# ##### Show image example in each class

# %%
# Define the classes of your dataset
classes = image_dataset.classes

# Create a figure with subplots for each class
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Loop through each class and plot the first image
for i, cls in enumerate(classes):
    # Get the indices of the images for this class
    indices = [j for j, (x, y) in enumerate(image_dataset) if y == i]
    # Get the first image for this class
    img = image_dataset[indices[0]][0]
    img = img.resize((256,256))
    # Plot the image on the corresponding subplot
    axes[i].imshow(img)
    axes[i].set_title(cls)

plt.show()

# %% [markdown]
# ##### Create image preprocessing

# %%
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize( [0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])

# %% [markdown]
# ##### Show image transformation

# %%
image_dataset = datasets.ImageFolder(root='Dataset/train/')

example_image, _ = image_dataset[0]
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(example_image)
ax[0].set_title('Before transform')
transformed_image = transform(example_image)
ax[1].imshow(transformed_image.permute(1, 2, 0))
ax[1].set_title('After transform')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### AlexNet Model Building

# %% [markdown]
# ##### Hyperparameter Setup

# %%
num_classes = 2
batch_size = 64
num_epochs = 64
learning_rate = 0.0001

# %% [markdown]
# ##### Apply preprocessing to transform the dataset

# %%
train_set = datasets.ImageFolder(root='Dataset/train/', transform=transform)
train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True)

val_set = datasets.ImageFolder(root='Dataset/val/', transform=transform)
val_loader = torch.utils.data.DataLoader(val_set, batch_size=batch_size, shuffle=False)

test_set = datasets.ImageFolder(root='Dataset/test/', transform=transform)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ##### Load pre-trained AlexNet model

# %%
model = models.alexnet(pretrained=True)

# %%
# Freeze all layers in the pre-trained model
for param in model.parameters():
    param.requires_grad = False

# %%
# Replace the last fully connected layer with a new one
num_ftrs = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_ftrs, 10)

# %% [markdown]
# ##### Define loss function and optimizer

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.classifier[6].parameters(), lr=learning_rate)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ### Train and Validate Model

# %% [markdown]
# ##### Train the model

# %%
# Train the model
train_losses = []
train_accs = []
val_losses = []
val_accs = []

# Iterate over the validation dataset in batches
train_predictions = np.array([])
train_ground_truths = np.array([])

for epoch in range(num_epochs):
    # Training
    model.train()
    train_loss = 0.0
    train_total = 0
    train_correct = 0
    
    for i, (images, labels) in enumerate(train_loader):
        images = images.cuda()
        labels = labels.cuda()
        
        optimizer.zero_grad()
        
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item() * labels.size(0)
        _, predicted = torch.max(outputs.data, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()
        
    train_losses.append(train_loss/train_total)
    train_accs.append(train_correct/train_total)
    
    # Validation
    model.eval()
    val_loss = 0.0
    val_total = 0
    val_correct = 0
    
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.cuda()
            labels = labels.cuda()
            
            outputs = model(images)
            loss = criterion(outputs, labels)

            train_predictions = np.concatenate((train_predictions, predicted.cpu().numpy()))
            train_ground_truths = np.concatenate((train_ground_truths, labels.cpu().numpy()))

            val_loss += loss.item() * labels.size(0)
            _, predicted = torch.max(outputs.data, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()
        
        # remove the extra predictions
        if len(train_predictions) > len(train_ground_truths):
            train_predictions = train_predictions[:len(train_ground_truths)]

    # Convert predictions and true labels to numpy arrays
    train_predictions = np.array(train_predictions)
    train_ground_truths = np.array(train_ground_truths)
    
    val_losses.append(val_loss/val_total)
    val_accs.append(val_correct/val_total)
    
    # Print epoch statistics
    print('Epoch [{}/{}], Train Loss: {:.4f}, Train Acc: {:.4f}, Val Loss: {:.4f}, Val Acc: {:.4f}'
          .format(epoch+1, num_epochs, train_losses[-1], train_accs[-1], val_losses[-1], val_accs[-1]))
# Out:
# Epoch [1/64], Train Loss: 1.0428, Train Acc: 0.5614, Val Loss: 0.6365, Val Acc: 0.7153
# Epoch [2/64], Train Loss: 0.5413, Train Acc: 0.7743, Val Loss: 0.4929, Val Acc: 0.8117
# Epoch [3/64], Train Loss: 0.4493, Train Acc: 0.8299, Val Loss: 0.4151, Val Acc: 0.8523
# Epoch [4/64], Train Loss: 0.3986, Train Acc: 0.8469, Val Loss: 0.3730, Val Acc: 0.8730
# Epoch [5/64], Train Loss: 0.3581, Train Acc: 0.8672, Val Loss: 0.3425, Val Acc: 0.8883
# Epoch [6/64], Train Loss: 0.3418, Train Acc: 0.8688, Val Loss: 0.3316, Val Acc: 0.8829
# Epoch [7/64], Train Loss: 0.3248, Train Acc: 0.8749, Val Loss: 0.3141, Val Acc: 0.8892
# Epoch [8/64], Train Loss: 0.3156, Train Acc: 0.8814, Val Loss: 0.2987, Val Acc: 0.8919
# Epoch [9/64], Train Loss: 0.3077, Train Acc: 0.8804, Val Loss: 0.2901, Val Acc: 0.8955
# Epoch [10/64], Train Loss: 0.2896, Train Acc: 0.8833, Val Loss: 0.2828, Val Acc: 0.8946
# Epoch [11/64], Train Loss: 0.2820, Train Acc: 0.8910, Val Loss: 0.2799, Val Acc: 0.8946
# Epoch [12/64], Train Loss: 0.2775, Train Acc: 0.8968, Val Loss: 0.2604, Val Acc: 0.9099
# Epoch [13/64], Train Loss: 0.2802, Train Acc: 0.8916, Val Loss: 0.2471, Val Acc: 0.9153
# Epoch [14/64], Train Loss: 0.2705, Train Acc: 0.8932, Val Loss: 0.2418, Val Acc: 0.9234
# Epoch [15/64], Train Loss: 0.2618, Train Acc: 0.8955, Val Loss: 0.2394, Val Acc: 0.9162
# Epoch [16/64], Train Loss: 0.2566, Train Acc: 0.8974, Val Loss: 0.2454, Val Acc: 0.9072
# Epoch [17/64], Train Loss: 0.2491, Train Acc: 0.9064, Val Loss: 0.2277, Val Acc: 0.9171
# Epoch [18/64], Train Loss: 0.2564, Train Acc: 0.8984, Val Loss: 0.2304, Val Acc: 0.9207
# Epoch [19/64], Train Loss: 0.2411, Train Acc: 0.9096, Val Loss: 0.2258, Val Acc: 0.9171
# Epoch [20/64], Train Loss: 0.2430, Train Acc: 0.9096, Val Loss: 0.2218, Val Acc: 0.9216
# Epoch [21/64], Train Loss: 0.2394, Train Acc: 0.9109, Val Loss: 0.2190, Val Acc: 0.9225
# Epoch [22/64], Train Loss: 0.2405, Train Acc: 0.9116, Val Loss: 0.2136, Val Acc: 0.9261
# Epoch [23/64], Train Loss: 0.2420, Train Acc: 0.9048, Val Loss: 0.2034, Val Acc: 0.9279
# Epoch [24/64], Train Loss: 0.2307, Train Acc: 0.9080, Val Loss: 0.2109, Val Acc: 0.9270
# Epoch [25/64], Train Loss: 0.2286, Train Acc: 0.9138, Val Loss: 0.2130, Val Acc: 0.9153
# Epoch [26/64], Train Loss: 0.2221, Train Acc: 0.9058, Val Loss: 0.1980, Val Acc: 0.9243
# Epoch [27/64], Train Loss: 0.2258, Train Acc: 0.9116, Val Loss: 0.2057, Val Acc: 0.9261
# Epoch [28/64], Train Loss: 0.2241, Train Acc: 0.9132, Val Loss: 0.2047, Val Acc: 0.9270
# Epoch [29/64], Train Loss: 0.2178, Train Acc: 0.9161, Val Loss: 0.1945, Val Acc: 0.9297
# Epoch [30/64], Train Loss: 0.2082, Train Acc: 0.9228, Val Loss: 0.1906, Val Acc: 0.9315
# Epoch [31/64], Train Loss: 0.2132, Train Acc: 0.9186, Val Loss: 0.1913, Val Acc: 0.9288
# Epoch [32/64], Train Loss: 0.2073, Train Acc: 0.9215, Val Loss: 0.1825, Val Acc: 0.9414
# Epoch [33/64], Train Loss: 0.2093, Train Acc: 0.9186, Val Loss: 0.1883, Val Acc: 0.9315
# Epoch [34/64], Train Loss: 0.2135, Train Acc: 0.9215, Val Loss: 0.1778, Val Acc: 0.9387
# Epoch [35/64], Train Loss: 0.1990, Train Acc: 0.9209, Val Loss: 0.1792, Val Acc: 0.9387
# Epoch [36/64], Train Loss: 0.2057, Train Acc: 0.9241, Val Loss: 0.1769, Val Acc: 0.9387
# Epoch [37/64], Train Loss: 0.1997, Train Acc: 0.9309, Val Loss: 0.1780, Val Acc: 0.9333
# Epoch [38/64], Train Loss: 0.2019, Train Acc: 0.9193, Val Loss: 0.1780, Val Acc: 0.9360
# Epoch [39/64], Train Loss: 0.1963, Train Acc: 0.9241, Val Loss: 0.1711, Val Acc: 0.9405
# Epoch [40/64], Train Loss: 0.2100, Train Acc: 0.9119, Val Loss: 0.1756, Val Acc: 0.9387
# Epoch [41/64], Train Loss: 0.2018, Train Acc: 0.9148, Val Loss: 0.1711, Val Acc: 0.9414
# Epoch [42/64], Train Loss: 0.1948, Train Acc: 0.9248, Val Loss: 0.1681, Val Acc: 0.9387
# Epoch [43/64], Train Loss: 0.1888, Train Acc: 0.9241, Val Loss: 0.1746, Val Acc: 0.9333
# Epoch [44/64], Train Loss: 0.1991, Train Acc: 0.9225, Val Loss: 0.1696, Val Acc: 0.9369
# Epoch [45/64], Train Loss: 0.1897, Train Acc: 0.9283, Val Loss: 0.1675, Val Acc: 0.9423
# Epoch [46/64], Train Loss: 0.1869, Train Acc: 0.9264, Val Loss: 0.1730, Val Acc: 0.9360
# Epoch [47/64], Train Loss: 0.1903, Train Acc: 0.9267, Val Loss: 0.1670, Val Acc: 0.9423
# Epoch [48/64], Train Loss: 0.1890, Train Acc: 0.9264, Val Loss: 0.1799, Val Acc: 0.9270
# Epoch [49/64], Train Loss: 0.1801, Train Acc: 0.9357, Val Loss: 0.1782, Val Acc: 0.9270
# Epoch [50/64], Train Loss: 0.1834, Train Acc: 0.9280, Val Loss: 0.1485, Val Acc: 0.9523
# Epoch [51/64], Train Loss: 0.1855, Train Acc: 0.9283, Val Loss: 0.1615, Val Acc: 0.9405
# Epoch [52/64], Train Loss: 0.1865, Train Acc: 0.9309, Val Loss: 0.1689, Val Acc: 0.9378
# Epoch [53/64], Train Loss: 0.1787, Train Acc: 0.9289, Val Loss: 0.1708, Val Acc: 0.9387
# Epoch [54/64], Train Loss: 0.1932, Train Acc: 0.9215, Val Loss: 0.1577, Val Acc: 0.9459
# Epoch [55/64], Train Loss: 0.1795, Train Acc: 0.9315, Val Loss: 0.1581, Val Acc: 0.9369
# Epoch [56/64], Train Loss: 0.1797, Train Acc: 0.9405, Val Loss: 0.1478, Val Acc: 0.9505
# Epoch [57/64], Train Loss: 0.1789, Train Acc: 0.9341, Val Loss: 0.1542, Val Acc: 0.9396
# Epoch [58/64], Train Loss: 0.1858, Train Acc: 0.9277, Val Loss: 0.1588, Val Acc: 0.9477
# Epoch [59/64], Train Loss: 0.1811, Train Acc: 0.9338, Val Loss: 0.1482, Val Acc: 0.9505
# Epoch [60/64], Train Loss: 0.1811, Train Acc: 0.9328, Val Loss: 0.1626, Val Acc: 0.9342
# Epoch [61/64], Train Loss: 0.1814, Train Acc: 0.9328, Val Loss: 0.1551, Val Acc: 0.9432
# Epoch [62/64], Train Loss: 0.1892, Train Acc: 0.9283, Val Loss: 0.1612, Val Acc: 0.9414
# Epoch [63/64], Train Loss: 0.1747, Train Acc: 0.9315, Val Loss: 0.1445, Val Acc: 0.9486
# Epoch [64/64], Train Loss: 0.1752, Train Acc: 0.9344, Val Loss: 0.1544, Val Acc: 0.9459

# %% [markdown]
# ##### Plot losses and accuracy

# %%
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.legend()
plt.show()

plt.plot(train_accs, label='Train Acc')
plt.plot(val_accs, label='Val Acc')
plt.legend()
plt.show()

# %% [markdown]
# ##### Calculate the confusion matrix

# %%
cm = confusion_matrix(train_ground_truths, train_predictions)
labels_category = ['Defected', 'Undefected']
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels= labels_category, yticklabels=labels_category)
# Out:
# <Axes: >

# %% [markdown]
# ##### Calculate the evaluation matrix

# %%
accuracy = accuracy_score(train_ground_truths, train_predictions)
precision = precision_score(train_ground_truths, train_predictions, average='binary', pos_label='Defected')
recall = recall_score(train_ground_truths, train_predictions, average='binary', pos_label='Defected')
f1 = f1_score(train_ground_truths, train_predictions, average='binary', pos_label='Defected')

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")

# %% [markdown]
# ### Testing Model

# %% [markdown]
# ##### Set to evaluation mode

# %%
# Set the model to evaluation mode
model.eval()

# Keep track of the validation loss and accuracy
test_loss = 0.0
test_correct = 0
test_total = 0

# %% [markdown]
# ##### Test the model

# %%
# Iterate over the validation dataset in batches
test_predictions = []
test_ground_truths = []

for images, labels in test_loader:
    images = images.cuda()
    labels = labels.cuda()
    # Forward pass
    outputs = model(images)
    loss = criterion(outputs, labels)

    # Update the validation loss
    test_loss += loss.item() * labels.size(0)

    test_predictions.extend(predicted.cpu().numpy())
    test_ground_truths.extend(labels.cpu().numpy())

    # Update the testing accuracy
    _, predicted = torch.max(outputs.data, 1)
    test_total += labels.size(0)
    test_correct += (predicted == labels).sum().item()

# Compute the average testing loss and accuracy
test_loss /= len(test_set)
test_accuracy = 100 * test_correct / test_total

# Print the testing loss and accuracy
print(f'Testing loss: {test_loss:.4f}, accuracy: {test_accuracy:.2f}%')
# Out:
# Testing loss: 0.1580, accuracy: 93.87%

# %% [markdown]
# ##### Calculate the confusion matrix

# %%
# Calculate the confusion matrix
cm = confusion_matrix(test_ground_truths, test_predictions)
labels_category = ['Defected', 'Undefected']
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels= labels_category, yticklabels=labels_category)
# Out:
# <Axes: >

# %% [markdown]
# ##### Calculate the evaluation matrix

# %%
accuracy = accuracy_score(test_ground_truths, test_predictions)
precision = precision_score(test_ground_truths, test_predictions, average='binary', pos_label='Defected')
recall = recall_score(test_ground_truths, test_predictions, average='binary', pos_label='Defected')
f1 = f1_score(test_ground_truths, test_predictions, average='binary', pos_label='Defected')

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")

# %% [markdown]
# ##### Save the model

# %%
# Save the state_dict model to a file
torch.save(model.state_dict(), 'alexnet-coffee-defect-state-dict.pth')

# Save the model to a file
torch.save(model, 'alexnet-coffee-defect.pth')
